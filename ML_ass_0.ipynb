# %%
a = float(input("Enter first num: "))
b = float(input("Enter second num: "))

print("Simple Calculator")
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
print("5.Mod")

ch = input("Enter choice: ")
match ch:
    case '1':
        print("Result:",a+b)
    case '2':
        print("Result:",a-b)
    case '3':
        print("Result:",a*b)
    case '4':
        print("Result:",a/b if b!=0 else "Error!!")
    case '5':
        print("Result:",a%b)
    case _:
        print("Invalid choice")
# Out:
# Enter first num:  23
# Enter second num:  2
# Simple Calculator
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Mod
# Enter choice:  5
# Result: 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = float(input("x1: "))
y1 = float(input("y1: "))
x2 = float(input("x2: "))
y2 = float(input("y2: "))

x = np.array([x1, x2])
y = np.array([y1, y2])

plt.plot(x, y, 'o-')
plt.axis('equal')
plt.show()
# Out:
# x1:  1
# y1:  2
# x2:  4
# y2:  2
